# %%
! mkdir ~/.kaggle

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# 2023-09-23 08:13:38.413373: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 54.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 24.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d mikhailklemin/kinopoisks-movies-reviews
# Out:
# ...
#  94% 209M/222M [00:02<00:00, 123MB/s]
# 100% 222M/222M [00:02<00:00, 109MB/s]

# %%
! unzip kinopoisks-movies-reviews.zip

# %%
nlp = spacy.load("ru_core_news_sm")

# %%
data = {'Text': [], 'Sentiment': []}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
# Empty DataFrame
# Columns: [Text, Sentiment]
# Index: []

# %%
from os import walk

mypath1 = "/content/dataset/neg"
filenames_neg = next(walk(mypath1), (None, None, []))[2]

# %%
index = 0
for item in filenames_neg:
  path = mypath1+"/"+item
  with open(path) as file:
      s = (file.readlines())
      text=""
      for i in range (len(s)):
          text+=s[i]
      df.at[index, "Text"] = text
      df.at[index, "Sentiment"] = "negative"
      index+=1
df
# Out:
#                                                     Text Sentiment
# 0      Безмерная тоска – так и только так можно охара...  negative
# 1      Насколько был хорош мультфильм «Князь Владимир...  negative
# 2      Нескольких женщин похищают и продают на рынке....  negative
# 3      Все части чужого были пропитаны искренней любо...  negative
# 4      Что мы делаем?..  Этот вопрос задаёт себе глав...  negative
# ...                                                  ...       ...
# 19822  Где – то три года тому назад на телеканале «СТ...  negative
# 19823  Более тупого сериала даже трудно себе представ...  negative
# 19824  Фильм не передает смысл песен, сам сюжет очень...  negative
# 19825  Перед тем как начать изложение своего мнения о...  negative
# 19826  Фильм, начинающийся, как байопик об очередном ...  negative
#
# [19827 rows x 2 columns]

# %%
from random import shuffle
mypath2 = "/content/dataset/pos"
filenames_pos = next(walk(mypath2), (None, None, []))[2] # тут оказывается 80000 примеров(слишком много)
shuffle(filenames_pos)
filenames_pos = filenames_pos[:19826]

# %%
for item in filenames_pos:
  path = mypath2+"/"+item
  with open(path) as file:
      s = (file.readlines())
      text=""
      for i in range (len(s)):
          text+=s[i]
      df.at[index, "Text"] = text
      df.at[index, "Sentiment"] = "positive"
      index+=1
df
# Out:
#                                                     Text Sentiment
# 0      Безмерная тоска – так и только так можно охара...  negative
# 1      Насколько был хорош мультфильм «Князь Владимир...  negative
# 2      Нескольких женщин похищают и продают на рынке....  negative
# 3      Все части чужого были пропитаны искренней любо...  negative
# 4      Что мы делаем?..  Этот вопрос задаёт себе глав...  negative
# ...                                                  ...       ...
# 39648  Не выдающееся, иногда топорное и даже робкое в...  positive
# 39649  Посмотрела я фильм Свадебная ваза дважды, втор...  positive
# 39650  Заставить человека плакать над фильмом непрост...  positive
# 39651  Кто же не слышал про Джэймса Кэмерона, который...  positive
# 39652  Стыдно сказать, но не сразу обратил внимание н...  positive
#
# [39653 rows x 2 columns]

# %%
len(filenames_pos)
# Out:
# 87138

# %%
import spacy
import pandas as pd

from tqdm import tqdm
from spacy.tokens import DocBin

# %%
df = df.sample(frac=0.5)
df
# Out:
#                                                     Text Sentiment
# 9329   Это первый и единственный проект Роя Андерссон...  negative
# 19140  Когда то очень давно Джордж Ромеро полюбил тем...  negative
# 32460  Отличная дорама для любителей пары Кан Шин У +...  positive
# 13265  Кэтрин Бигелоу давно считается в Голливуде авт...  negative
# 36297  Художественный фильм о силе детского воображен...  positive
# ...                                                  ...       ...
# 5764   Всем привет, специально зарегистрировался чтоб...  negative
# 35049  Это кино определенно стоит посмотреть, хотя бы...  positive
# 21237  Да-да, я уже много где, слышала и читала о том...  positive
# 24481  'Ярмарка тщеславия'-отличная экранизация, отли...  positive
# 29647  Фильм Дэвида О. Рассела «Боец», основанный на ...  positive
#
# [19826 rows x 2 columns]

# %%
df = df.reset_index()
df
# Out:
#        index                                               Text Sentiment
# 0       9329  Это первый и единственный проект Роя Андерссон...  negative
# 1      19140  Когда то очень давно Джордж Ромеро полюбил тем...  negative
# 2      32460  Отличная дорама для любителей пары Кан Шин У +...  positive
# 3      13265  Кэтрин Бигелоу давно считается в Голливуде авт...  negative
# 4      36297  Художественный фильм о силе детского воображен...  positive
# ...      ...                                                ...       ...
# 19821   5764  Всем привет, специально зарегистрировался чтоб...  negative
# 19822  35049  Это кино определенно стоит посмотреть, хотя бы...  positive
# 19823  21237  Да-да, я уже много где, слышала и читала о том...  positive
# 19824  24481  'Ярмарка тщеславия'-отличная экранизация, отли...  positive
# 19825  29647  Фильм Дэвида О. Рассела «Боец», основанный на ...  positive
#
# [19826 rows x 3 columns]

# %%
del df["index"]
df
# Out:
#                                                     Text Sentiment
# 0      Это первый и единственный проект Роя Андерссон...  negative
# 1      Когда то очень давно Джордж Ромеро полюбил тем...  negative
# 2      Отличная дорама для любителей пары Кан Шин У +...  positive
# 3      Кэтрин Бигелоу давно считается в Голливуде авт...  negative
# 4      Художественный фильм о силе детского воображен...  positive
# ...                                                  ...       ...
# 19821  Всем привет, специально зарегистрировался чтоб...  negative
# 19822  Это кино определенно стоит посмотреть, хотя бы...  positive
# 19823  Да-да, я уже много где, слышала и читала о том...  positive
# 19824  'Ярмарка тщеславия'-отличная экранизация, отли...  positive
# 19825  Фильм Дэвида О. Рассела «Боец», основанный на ...  positive
#
# [19826 rows x 2 columns]

# %%
df['Sentiment'].value_counts()
# Out:
# negative    10018
# positive     9808
# Name: Sentiment, dtype: int64

# %%
data = [tuple(df.iloc[i].values) for i in range(df.shape[0])]
len(data)
# Out:
# 19826

# %%
df['Sentiment'].value_counts()
# Out:
# negative    10018
# positive     9808
# Name: Sentiment, dtype: int64

# %%
train_data = data[:15000]
valid_data = data[4800:]

# %%
def make_docs(data):
    """
    this will take a list of texts and labels
    and transform them in spacy documents
    data: list(tuple(text, label))
    returns: List(spacy.Doc.doc)
    """
    docs = []
    # nlp.pipe([texts]) is way faster than running
    # nlp(text) for each text
    # as_tuples allows us to pass in a tuple,
    # the first one is treated as text
    # the second one will get returned as it is.
    # a = tqdm(nlp.pipe(data, as_tuples=True), total = len(data))
    for doc, label in tqdm(nlp.pipe(data, as_tuples=True), total = len(data)):
        if label == 'negative':
            doc.cats["positive"] = 0
            doc.cats["negative"] = 1
        else:
            doc.cats["positive"] = 1
            doc.cats["negative"] = 0
        # we need to set the (text)cat(egory) for each document
        #doc.cats["positive"] = label
        # put them into a nice list
        docs.append(doc)
    return docs

# %%
# we are so far only interested in the first 5000 reviews
# this will keep the training time short.
# In practice take as much data as you can get.
# you can always reduce it to make the script even faster.
num_texts = 5000
# first we need to transform all the training data
train_docs = make_docs(train_data[:num_texts])
# Out:
# 100%|██████████| 5000/5000 [13:04<00:00,  6.38it/s]

# %%
# then we save it in a binary file to disc
doc_bin = DocBin(docs=train_docs)
doc_bin.to_disk("train.spacy")
# repeat for validation data
valid_docs = make_docs(valid_data[:4800])
doc_bin = DocBin(docs=valid_docs)
doc_bin.to_disk("valid.spacy")
# Out:
# 100%|██████████| 4800/4800 [12:45<00:00,  6.27it/s]

# %%
! python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2023-09-23 08:57:08.189766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev valid.spacy  --output ./output
# Out:
# 2023-09-23 09:01:30.243815: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ℹ Saving to output directory: output
# ℹ Using CPU
# ℹ To switch to GPU 0, use the option: --gpu-id 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTCAT  CATS_SCORE  SCORE
# ---  ------  ------------  ----------  ------
#   0       0          0.25       33.10    0.33
#   0     200         59.70       66.53    0.67
#   0     400         37.80       75.74    0.76
#   0     600         32.40       72.61    0.73
#   0     800         27.17       74.81    0.75
#   0    1000         27.60       83.10    0.83
#   0    1200         25.21       84.52    0.85
#   0    1400         22.88       84.60    0.85
# ...

# %%
import spacy
# load thebest model from training
nlp = spacy.load("output/model-best")
text = ""
print("type : ‘quit’ to exit")
# predict the sentiment until someone writes quit
while text != "quit":
    text = input("Please enter example input: ")
    doc = nlp(text)
    print(doc.cats)
    if doc.cats['positive'] >.5:
        print(f"the sentiment is positive")
    else:
        print(f"the sentiment is negative")
# Out:
# type : ‘quit’ to exit
# Please enter example input: смотрела этот фильм 10 раз мой самый любимый
# {'positive': 0.8716211915016174, 'negative': 0.12837883830070496}
# the sentiment is positive
# Please enter example input: жаль, что далеко не все поймут смысл фильма)))) действительно тонко))))) не так уж много и образованных в наше время, кто знает, почему он такой интересный и необычный))))
# {'positive': 0.7560555338859558, 'negative': 0.243944451212883}
# the sentiment is positive
# Please enter example input: самое худшее что случалось в моей жизнь - этот фильм
# {'positive': 0.8151695132255554, 'negative': 0.18483051657676697}
# the sentiment is positive
# Please enter example input: да ладно. приколько же. мне понравилось
# {'positive': 0.5175267457962036, 'negative': 0.4824731945991516}
# the sentiment is positive
# Please enter example input: Бредово бредовая бредятина и сплошная повестка. Жаль потраченого времени
# ...
